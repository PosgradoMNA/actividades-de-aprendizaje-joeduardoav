# %% [markdown]
# **Curso de Python IBM. Módulo 1.**

# %% [markdown]
# * Función para imprimir texto plano: print(' ')
# * Insertar salto de línea: '\n'
# * Insertar comentario: #comentario

# %%
print('Hola, mundo')
print('Hola,\nmundo')
#print('Hola, mundo')
# Out:
# Hola, mundo
# Hola,
# mundo

# %% [markdown]
# Tipos de datos
# * Int - entero
# * Float - reales/decimales
# * String - cadenas
#
# Conversiones
#
# * float(2) -> 2.0
# * int(1.1) -> 1
# * int('1') -> 1
# * int('A') -> ERROR
# * str(1) -> '1'
# * int(True) -> 1
# * bool(1) -> True

# %%
print(bool(1))
# Out:
# True

# %% [markdown]
# Operandos y operadores
# * Números: operandos
# * Signos: operadores
# * 25/5 -> 5.0, genera un float
# * 25//4 -> 4, división entera
# * Jerarquía de operadores se *respeta*

# %% [markdown]
# Definir una variable
# * variable = x

# %%
x=50
x=x+1
y=x//2
print(y)
# Out:
# 25

# %% [markdown]
# Strings
#
# * Tratado como un arreglo que empieza en 0
# * O como un arreglo que termina en -1
# * String = 'Hola mundo'
# * String[0] -> una letra
# * String[0:3] -> imprimir del subíndice 0 al 2
# * String[::2] -> every second variable -> 'Hl ud'
# * String[0:5:2] -> every second variable, en un rango específico -> 'Hl '
# * len()
# * podemos sumar y multiplicar
#
# Nota
# * no puedo cambiar el valor de un solo char

# %% [markdown]
# Funciones
# * len()
# * upper()
# * replace('a sustituir', 'sustituto')
# * find()

# %%
name = 'Lizz'
print(name[0:2])
# Out:
# Li
